# %%
import sys
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]'

# %% [markdown]
# # Variable

# %%
i=1
i
# Out:
# 1

# %%
type(i)
# Out:
# int

# %%
a=5
b=3
c=a+b
print(c)
# Out:
# 8

# %%
a= 4
print(a)

a=5
print(a)
# Out:
# 4
# 5

# %%
first_name="m"
last_name="k"

full_name=first_name+" "+ last_name
print(full_name)
# Out:
# m k

# %%
a, b=5,6
print(a)
print(b)
# Out:
# 5
# 6

# %% [markdown]
# # Keyword

# %% [raw]
# Keyword are reserved words and can not used as identifier

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# # Identifier

# %% [raw]
# Identifier is a name given to class, function, variables etc.

# %%
1var=1 #variable can't start with digit
# Out:
#   Cell In[11], line 1
#     1var=1
#     ^
# SyntaxError: invalid decimal literal

# %%
val1@=1 #variable can't use special symbols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 val1@=1
#
# NameError: name 'val1' is not defined

# %%
import=1 #variable can't use reserved keywords
# Out:
#   Cell In[13], line 1
#     import=1
#           ^
# SyntaxError: invalid syntax

# %%
""" 
Correct way of defining an identifier 
(Identifiers can be a combination of letters in lowercase (a to z) or uppercase 
"""
val12=4
val12
# Out:
# 4

# %%
val_=55
val_
# Out:
# 55

# %% [markdown]
# # Comment

# %%
#Single line comment
val=10

# %%
#Multi
#line
#comment
val=10

# %%
'''
Multiline 
comment
'''
val=10

# %%
"""
Multiline
Comment
"""
val=10

# %% [markdown]
# # Statements

# %% [raw]
# - Instructions that a Python interpreter can execute.

# %%
p=20
q=20
r=q
p,type(p),hex(id(p))
# Out:
# (20, int, '0x7ff83a8ba608')

# %%
q,type(q),hex(id(q))
# Out:
# (20, int, '0x7ff83a8ba608')

# %%
r,type(r),hex(id(r))
# Out:
# (20, int, '0x7ff83a8ba608')

# %%
p=10
p=p+20 # Variable Overwriting 
p
# Out:
# 30

# %% [markdown]
# # Variable Assigment

# %%
a=10
b=10.2
c="hello"
print(a)
print(b)
print(c)
# Out:
# 10
# 10.2
# hello

# %% [markdown]
# # Multiple Assignments

# %%
a,b,c=10,10.2,"Hello"
print(a)
print(b)
print(c)
# Out:
# 10
# 10.2
# Hello

# %%
p=p1=p2=p3=p4=11
print(p,p1,p2,p3,p4)
# Out:
# 11 11 11 11 11

# %% [markdown]
# # Data Types

# %%
val1=10
print(val1)
print(type(val1))
print(sys.getsizeof(val1))
print(val1," is Integer?",isinstance(val1,int))
# Out:
# 10
# <class 'int'>
# 28
# 10  is Integer? True

# %%
val2=10.2
print(val2)
print(type(val1))
print(sys.getsizeof(val2))
print(val2," is float?",isinstance(val2,float))
# Out:
# 10.2
# <class 'int'>
# 24
# 10.2  is float? True

# %%
val3= 2+3j
print(val3)
print(type(val3))
print(sys.getsizeof(val3))
print(val3, " is complex?", isinstance(val3,complex))
# Out:
# (2+3j)
# <class 'complex'>
# 32
# (2+3j)  is complex? True

# %%
sys.getsizeof(int())
# Out:
# 28

# %%
sys.getsizeof(float())
# Out:
# 24

# %%
sys.getsizeof(complex())
# Out:
# 32

# %% [markdown]
# # Boolean

# %%
bool1=True
bool2=False
print(type(bool1))
print(type(bool2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
isinstance(bool1,bool)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # Strings

# %%
str="Hello World"
print(str)
# Out:
# Hello World

# %%
str1='Hello World'
print(str)
# Out:
# Hello World

# %%
str2='''Hello World'''
print(str2)
# Out:
# Hello World

# %%
str3="""Hello World"""
print(str3)
# Out:
# Hello World

# %%
str4=('hello '
'world '
'!!')
print(str4)
# Out:
# hello world !!

# %%
str5="wohoo "
str5=str5*6
print(str5)
# Out:
# wohoo wohoo wohoo wohoo wohoo wohoo

# %%
len(str5)
# Out:
# 36

# %% [markdown]
# # String Indexing

# %%
str="HELLO PYTHON"
print(str)
# Out:
# HELLO PYTHON

# %%
str[0]
# Out:
# 'H'

# %%
str[len(str)-1]  # Last character in string using len function
# Out:
# 'N'

# %%
len(str)
# Out:
# 12

# %%
str[-1]
# Out:
# 'N'

# %%
str[5]
# Out:
# ' '

# %%
str[6]
# Out:
# 'P'

# %% [markdown]
# # String Slicing

# %%
str[0:5]
# Out:
# 'HELLO'

# %%
str[-1:]
# Out:
# 'N'

# %%
str[6:11]
# Out:
# 'PYTHO'

# %%
str[-4:] # if nothing after colon means upto end ie. last index
# Out:
# 'THON'

# %%
str[:4] # if nothing before colon means at start ie.0
# Out:
# 'HELL'

# %% [markdown]
# # Update & Delete String

# %%
str
# Out:
# 'HELLO PYTHON'

# %%
str[0:5]="Hi" #Strings are immutable which means elements of a string cannot be changed once they have been assigned.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 str[0:5]="Hi" #Strings are immutable which means elements of a string cannot be changed once they have been assigned.
#
# TypeError: 'str' object does not support item assignment

# %%
del str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del str
#
# NameError: name 'str' is not defined

# %%
print(str)
# Out:
# <class 'str'>

# %% [markdown]
# # String concatenation

# %%
s1= "Hello "
s2= "World"
s3= s1+s2
print(s3)
# Out:
# Hello World

# %% [markdown]
# # String Slicing

# %%
si = 'hello'
si
# Out:
# 'hello'

# %%
si[0] #forward index
# Out:
# 'h'

# %%
si[-1] #backward index
# Out:
# 'o'

# %%
si[-3]
# Out:
# 'l'

# %%
si[:]
# Out:
# 'hello'

# %%
si[2:5]
# Out:
# 'llo'

# %%
s5 = 'welcome'
s5
# Out:
# 'welcome'

# %%
s5[1:4]
# Out:
# 'elc'

# %%
s5 = 'Welcome to Python world'
s5
# Out:
# 'Welcome to Python world'

# %%
s5[1:7]
# Out:
# 'elcome'

# %%
s5[2:]
# Out:
# 'lcome to Python world'

# %%
s5[:10]
# Out:
# 'Welcome to'

# %%
s5[::1]
# Out:
# 'Welcome to Python world'

# %%
s5[::2] #Move forward by 2 (skip one character)
# Out:
# 'Wloet yhnwrd'

# %%
s5[::10]
# Out:
# 'W r'

# %%
s5[::-1]
# Out:
# 'dlrow nohtyP ot emocleW'

# %%
s5[::-5]
# Out:
# 'd y l'

# %%
s5[1:20:10]
# Out:
# 'eP'

# %%
s2='Megha'
for i in s2:
    print(i)
# Out:
# M
# e
# g
# h
# a
