# %%
import cv2

# %%
import numpy as np

# %%
input =cv2.imread(r"D:\MEGH@\AI_Engineer\Practice\Live Class Practice\AI\dog.jpg")

# %%
input
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
cv2.imshow('Dog',input)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
print('Height of the image is:',input.shape[0],'pixels')
print('Width of the image is:',input.shape[1],'pixels')
print('Number of channels in the image is:',input.shape[2],'pixels')
# Out:
# Height of the image is: 148 pixels
# Width of the image is: 148 pixels
# Number of channels in the image is: 3 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True

# %%
import os
