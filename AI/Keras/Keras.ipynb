# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Create an image data generator with augmentations
datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.4,
    zoom_range=0.4,
    horizontal_flip=True,
    rescale=None,
    fill_mode='constant' #nearest, reflect, wrap, constant
)
# Load image from path
img = load_img(r"D:\MEGH@\AI_Engineer\Practice\Live Class Practice\AI\dog.jpg")  # ✅ Use backslash or raw string

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=148x148>

# %%
# Convert to numpy array
x = img_to_array(img)
x = x. reshape( (1, ) + x. shape)

# Generate augmented images and save
i = 0
for batch in datagen. flow(x, batch_size=1,
save_to_dir=r"D:\MEGH@\AI_Engineer\Practice\Live Class Practice\AI\Data Augumantation",
save_prefix='dog', save_format='jpeg'):

# Reshape to (1, height, width, channels)
    i += 1
    if i > 30:
        break # Prevent infinite loop
