# %%
def greet():
    print("Hello, World!")

# %%
def greet():
    print("Hello, World!")

greet()
# Out:
# Hello, World!

# %%
def greet():
    print("Hello, World!")

greet()

def greet():
    print("Hello, World!")
    
greet()
# Out:
# Hello, World!
# Hello, World!

# %%
def greet():
    print("Hello, World!")
    
greet()
greet()
# Out:
# Hello, World!
# Hello, World!

# %%
type(greet)
# Out:
# function

# %%
def greet():
    print("Hello, World!")
    
a=greet()
a
# Out:
# Hello, World!

# %%
type(a)
# Out:
# NoneType

# %%
def greet():
    return "Hello, World!"

a= greet()
a
# Out:
# 'Hello, World!'

# %%
type(a)
# Out:
# str
