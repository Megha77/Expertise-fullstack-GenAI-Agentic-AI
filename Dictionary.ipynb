# %% [markdown]
# <a href="https://colab.research.google.com/github/Megha77/Expertise-fullstack-GenAI-Agentic-AI/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dictionary

# %%
'''
Dictionary is a mutable data type in Python.
A python dictionary is a collection of key and value pairs separated by a colon (:) & enclosed
in curly braces {}.
Keys must be unique in a dictionary, duplicate values are allowed.
'''
# Out:
# '\nDictionary is a mutable data type in Python. \nA python dictionary is a collection of key and value pairs separated by a colon (:) & enclosed \nin curly braces {}. \nKeys must be unique in a dictionary, duplicate values are allowed. \n'

# %%
mydict=dict()
mydict
# Out:
# {}

# %%
mydict1={}
mydict
# Out:
# {}

# %%
mydict1={1:'one',2:'two',3:'three'}
mydict1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict=dict({1:'one',2:'two',3:'three'})
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict2={'A':'one','B':'two','C':'three'}
mydict2
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict3={'A':'one',2:'two','three':3}
mydict3
# Out:
# {'A': 'one', 2: 'two', 'three': 3}

# %%
mydict1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict1.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
mydict1.values()
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict1.items()
# Out:
# dict_items([(1, 'one'), (2, 'two'), (3, 'three')])

# %%
mydict4={1:'one',2:'two','A':['a','b','c'],'B':(1,'two','three')}
mydict4
# Out:
# {1: 'one', 2: 'two', 'A': ['a', 'b', 'c'], 'B': (1, 'two', 'three')}

# %%
mydict5={1:'one',2:'two','A':{'a':'rat','b':'bat','c':'mat'},'B':('one','two')}
mydict5
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'a': 'rat', 'b': 'bat', 'c': 'mat'},
#  'B': ('one', 'two')}

# %%
# Create a dictionary from a sequence of keys
keys={'a','b','c','d'}
mydict6=dict.fromkeys(keys)
mydict6
# Out:
# {'d': None, 'b': None, 'a': None, 'c': None}

# %%
keys={'a','b','c','d'}
value=10
mydict7=dict.fromkeys(keys,value)
mydict7
# Out:
# {'d': 10, 'b': 10, 'a': 10, 'c': 10}

# %%
keys={'a','b','c','d'}
value=[10,20,30]
mydict8=dict.fromkeys(keys,value)
mydict8
# Out:
# {'d': [10, 20, 30], 'b': [10, 20, 30], 'a': [10, 20, 30], 'c': [10, 20, 30]}

# %%
value.append(40)
mydict8
# Out:
# {'d': [10, 20, 30, 40, 40],
#  'b': [10, 20, 30, 40, 40],
#  'a': [10, 20, 30, 40, 40],
#  'c': [10, 20, 30, 40, 40]}

# %%
# Accessing Items

# %%
mydict={1:'one',2:'two',3:'three'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict[1]
# Out:
# 'one'

# %%
mydict.get(1)
# Out:
# 'one'

# %%
mydict1={'Name':'Andrew','ID':1234,'Job':'Data Engineer'}
mydict1['Name']
# Out:
# 'Andrew'

# %%
mydict1.get('Job')
# Out:
# 'Data Engineer'

# %%
# Add, Remove & Change Items

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict1['DOB']=1992
mydict1['Address']='Delhi'
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1={'DOB':1995}
mydict1.update(dict1)
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['Job']='Analyst'
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1995,
#  'Address': 'Delhi',
#  'Job': 'Analyst'}

# %%
mydict1.pop('Job')
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.popitem()
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1995}

# %%
del mydict1['ID']
mydict1
# Out:
# {'Name': 'Asif', 'DOB': 1995}

# %%
mydict1.clear()
mydict1
# Out:
# {}

# %%
del mydict1
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_754/1059459225.py in <cell line: 0>()
#       1 del mydict1
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %%
# Copy Dictionary

# %%
mydict = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki'}
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
mydict2=mydict
mydict2
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(mydict)
# Out:
# 132120738325952

# %%
id(mydict2)
# Out:
# 132120738325952

# %%
mydict3=mydict.copy()
mydict3
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
id(mydict3)
# Out:
# 132120738327232

# %%
mydict['Address']='Mumbai'
mydict
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict2 # mydict2 will be also impacted as it is pointing to the same dictionary
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Mumbai'}

# %%
mydict3 # Copy of list won't be impacted due to the changes made in the original
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Address': 'Hilsinki'}

# %%
# Loop through a Dictionary

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Address' : 'Hilsinki' ,'Job':'Analyst'}
mydict1
# Out:
# {'Name': 'Asif',
#  'ID': 12345,
#  'DOB': 1991,
#  'Address': 'Hilsinki',
#  'Job': 'Analyst'}

# %%
for i in mydict1:
  print(i, ':-', mydict1[i])
# Out:
# Name :- Asif
# ID :- 12345
# DOB :- 1991
# Address :- Hilsinki
# Job :- Analyst

# %%
for i in mydict1:
  print(mydict1[i])
# Out:
# Asif
# 12345
# 1991
# Hilsinki
# Analyst

# %%
# Dictionary Membership

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1
# Out:
# True

# %%
'Asif' in mydict1 # Membership test can be only done for keys.
# Out:
# False

# %%
'Job' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# False

# %% [markdown]
# All / Any
#
# The all() method returns:
# True - If all all keys of the dictionary are true
# False - If any key of the dictionary is false
# The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'}
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1)
# Out:
# True

# %%
any(mydict1)
# Out:
# True
