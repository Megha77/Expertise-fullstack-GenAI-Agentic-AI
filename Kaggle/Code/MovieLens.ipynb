# %% [markdown]
# # MovieLens 20M Dataset

# %%
# https://www.kaggle.com/datasets/grouplens/movielens-20m-dataset === ( dataset download link) 

# https://www.kaggle.com/code/harunshimanto/pandas-with-data-science-ai === (code link) == work till 44th line

# %%
import pandas as pd

# %%
movies=pd.read_csv(r'D:\MEGH@\AI_Engineer\Practice\Expertise-fullstack-GenAI-Agentic-AI\Kaggle\File\movie.csv')

# %%
print(type(movies))
movies.head(20)
# Out:
# <class 'pandas.DataFrame'>
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 7         8                    Tom and Huck (1995)
# 8         9                    Sudden Death (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 12       13                           Balto (1995)
# 13       14                           Nixon (1995)
# 14       15                Cutthroat Island (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# ...

# %%
tags=pd.read_csv(r'D:\MEGH@\AI_Engineer\Practice\Expertise-fullstack-GenAI-Agentic-AI\Kaggle\File\tag.csv')

# %%
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
ratings=pd.read_csv(r'D:\MEGH@\AI_Engineer\Practice\Expertise-fullstack-GenAI-Agentic-AI\Kaggle\File\rating.csv')
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
row_0=tags.iloc[0]
type(row_0)
# Out:
# pandas.Series

# %%
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
row_0['userId']
# Out:
# np.int64(18)
